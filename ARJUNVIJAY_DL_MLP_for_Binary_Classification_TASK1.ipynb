# %% [markdown]
# <a href="https://colab.research.google.com/github/ARJUNVIJAYMK/ML-DL_assignment/blob/my_sql_assignment/ARJUNVIJAY_DL_MLP_for_Binary_Classification_TASK1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **IMPORT LIBRARY**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.initializers import he_normal
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # **LOAD THE DATA**

# %%
# !wget -O data.csv https://raw.githubusercontent.com/jbrownlee/Datasets/master/ionosphere.csv
# Out:
# --2024-01-07 04:50:19--  https://raw.githubusercontent.com/jbrownlee/Datasets/master/ionosphere.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 76466 (75K) [text/plain]
# Saving to: ‘data.csv’
#
# data.csv            100%[===================>]  74.67K  --.-KB/s    in 0.01s
#
# 2024-01-07 04:50:19 (5.86 MB/s) - ‘data.csv’ saved [76466/76466]

# %% [markdown]
# # **READ CSV FILE**

# %%
df = pd.read_csv("data.csv")
df
# Out:
#      1  0  0.99539  -0.05889  0.85243  0.02306  0.83398  -0.37708      1.1  \
# 0    1  0  1.00000  -0.18829  0.93035 -0.36156 -0.10868  -0.93597  1.00000
# 1    1  0  1.00000  -0.03365  1.00000  0.00485  1.00000  -0.12062  0.88965
# 2    1  0  1.00000  -0.45161  1.00000  1.00000  0.71216  -1.00000  0.00000
# 3    1  0  1.00000  -0.02401  0.94140  0.06531  0.92106  -0.23255  0.77152
# 4    1  0  0.02337  -0.00592 -0.09924 -0.11949 -0.00763  -0.11824  0.14706
# ..  .. ..      ...       ...      ...      ...      ...       ...      ...
# 345  1  0  0.83508   0.08298  0.73739 -0.14706  0.84349  -0.05567  0.90441
# 346  1  0  0.95113   0.00419  0.95183 -0.02723  0.93438  -0.01920  0.94590
# 347  1  0  0.94701  -0.00034  0.93207 -0.03227  0.95177  -0.03431  0.95584
# 348  1  0  0.90608  -0.01657  0.98122 -0.01989  0.95691  -0.03646  0.85746
# 349  1  0  0.84710   0.13533  0.73638 -0.06151  0.87873   0.08260  0.88928
#
#      0.03760  ...  -0.51171  0.41078  -0.46168  0.21266  -0.34090  0.42267  \
# 0   -0.04549  ...  -0.26569 -0.20468  -0.18401 -0.19040  -0.11593 -0.16626
# 1    0.01198  ...  -0.40220  0.58984  -0.22145  0.43100  -0.17365  0.60436
# 2    0.00000  ...   0.90695  0.51613   1.00000  1.00000  -0.20099  0.25682
# 3   -0.16399  ...  -0.65158  0.13290  -0.53206  0.02431  -0.62197 -0.05707
# 4    0.06637  ...  -0.01535 -0.03240   0.09223 -0.07859   0.00732  0.00000
# ..       ...  ...       ...      ...       ...      ...       ...      ...
# 345 -0.04622  ...  -0.04202  0.83479   0.00123  1.00000   0.12815  0.86660
# 346  0.01606  ...   0.01361  0.93522   0.04925  0.93159   0.08168  0.94066
# 347  0.02446  ...   0.03193  0.92489   0.02542  0.92120   0.02242  0.92459
# 348  0.00110  ...  -0.02099  0.89147  -0.07760  0.82983  -0.17238  0.96022
# 349 -0.09139  ...  -0.15114  0.81147  -0.04822  0.78207  -0.00703  0.75747
#
#      -0.54487  0.18641  -0.45300  g
# 0    -0.06288 -0.13738  -0.02447  b
# 1    -0.24180  0.56045  -0.38238  g
# 2     1.00000 -0.32382   1.00000  b
# 3    -0.59573 -0.04608  -0.65697  g
# 4     0.00000 -0.00039   0.12011  b
# ..        ...      ...       ... ..
# 345  -0.10714  0.90546  -0.04307  g
# 346  -0.00035  0.91483   0.04712  g
# 347   0.00442  0.92697  -0.00577  g
# 348  -0.03757  0.87403  -0.16243  g
# 349  -0.06678  0.85764  -0.06151  g
#
# [350 rows x 35 columns]

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of      1  0  0.99539  -0.05889  0.85243  0.02306  0.83398  -0.37708      1.1  \
# 0    1  0  1.00000  -0.18829  0.93035 -0.36156 -0.10868  -0.93597  1.00000
# 1    1  0  1.00000  -0.03365  1.00000  0.00485  1.00000  -0.12062  0.88965
# 2    1  0  1.00000  -0.45161  1.00000  1.00000  0.71216  -1.00000  0.00000
# 3    1  0  1.00000  -0.02401  0.94140  0.06531  0.92106  -0.23255  0.77152
# 4    1  0  0.02337  -0.00592 -0.09924 -0.11949 -0.00763  -0.11824  0.14706
# ..  .. ..      ...       ...      ...      ...      ...       ...      ...
# 345  1  0  0.83508   0.08298  0.73739 -0.14706  0.84349  -0.05567  0.90441
# 346  1  0  0.95113   0.00419  0.95183 -0.02723  0.93438  -0.01920  0.94590
# 347  1  0  0.94701  -0.00034  0.93207 -0.03227  0.95177  -0.03431  0.95584
# 348  1  0  0.90608  -0.01657  0.98122 -0.01989  0.95691  -0.03646  0.85746
# 349  1  0  0.84710   0.13533  0.73638 -0.06151  0.87873   0.08260  0.88928
#
#      0.03760  ...  -0.51171  0.41078  -0.46168  0.21266  -0.34090  0.42267  \
# 0   -0.04549  ...  -0.26569 -0.20468  -0.18401 -0.19040  -0.11593 -0.16626
# 1    0.01198  ...  -0.40220  0.58984  -0.22145  0.43100  -0.17365  0.60436
# 2    0.00000  ...   0.90695  0.51613   1.00000  1.00000  -0.20099  0.25682
# 3   -0.16399  ...  -0.65158  0.13290  -0.53206  0.02431  -0.62197 -0.05707
# 4    0.06637  ...  -0.01535 -0.03240   0.09223 -0.07859   0.00732  0.00000
# ..       ...  ...       ...      ...       ...      ...       ...      ...
# 345 -0.04622  ...  -0.04202  0.83479   0.00123  1.00000   0.12815  0.86660
# 346  0.01606  ...   0.01361  0.93522   0.04925  0.93159   0.08168  0.94066
# 347  0.02446  ...   0.03193  0.92489   0.02542  0.92120   0.02242  0.92459
# 348  0.00110  ...  -0.02099  0.89147  -0.07760  0.82983  -0.17238  0.96022
# 349 -0.09139  ...  -0.15114  0.81147  -0.04822  0.78207  -0.00703  0.75747
#
#      -0.54487  0.18641  -0.45300  g
# 0    -0.06288 -0.13738  -0.02447  b
# 1    -0.24180  0.56045  -0.38238  g
# 2     1.00000 -0.32382   1.00000  b
# 3    -0.59573 -0.04608  -0.65697  g
# 4     0.00000 -0.00039   0.12011  b
# ..        ...      ...       ... ..
# 345  -0.10714  0.90546  -0.04307  g
# 346  -0.00035  0.91483   0.04712  g
# 347   0.00442  0.92697  -0.00577  g
# 348  -0.03757  0.87403  -0.16243  g
# 349  -0.06678  0.85764  -0.06151  g
#
# [350 rows x 35 columns]>

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
X
# Out:
# array([[ 1.     ,  0.     ,  1.     , ..., -0.06288, -0.13738, -0.02447],
#        [ 1.     ,  0.     ,  1.     , ..., -0.2418 ,  0.56045, -0.38238],
#        [ 1.     ,  0.     ,  1.     , ...,  1.     , -0.32382,  1.     ],
#        ...,
#        [ 1.     ,  0.     ,  0.94701, ...,  0.00442,  0.92697, -0.00577],
#        [ 1.     ,  0.     ,  0.90608, ..., -0.03757,  0.87403, -0.16243],
#        [ 1.     ,  0.     ,  0.8471 , ..., -0.06678,  0.85764, -0.06151]])

# %%
y
# Out:
# array(['b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b',
#        'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g',
#        'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b',
#        'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g',
#        'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b',
#        'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g',
#        'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b',
#        'g', 'b', 'g', 'b', 'g', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b',
#        'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g',
#        'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b',
#        'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g',
#        'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b',
#        'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g',
#        'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b',
#        'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g',
#        'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b',
#        'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g',
#        'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b',
#        'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g', 'b', 'g',
#        'b', 'g', 'b', 'g', 'b', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g',
#        'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g',
#        'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g',
#        'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g',
#        'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g',
#        'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g',
#        'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g',
#        'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g', 'g'],
#       dtype=object)

# %% [markdown]
# # **LABEL ENCODING**

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %% [markdown]
# # ** Split the data into training and testing sets**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# # **CREATE MLP MODEL**

# %%
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu', kernel_initializer=he_normal()))
model.add(Dense(32, activation='relu', kernel_initializer=he_normal()))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# # **COMPILE THE MODEL**

# %%
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=50, batch_size=32, verbose=1)
# Out:
# Epoch 1/50
# 8/8 [==============================] - 1s 4ms/step - loss: 0.7554 - accuracy: 0.4573
# Epoch 2/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.5539 - accuracy: 0.7949
# Epoch 3/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4751 - accuracy: 0.7991
# Epoch 4/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.4272 - accuracy: 0.8376
# Epoch 5/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3865 - accuracy: 0.8761
# Epoch 6/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3489 - accuracy: 0.9103
# Epoch 7/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.3211 - accuracy: 0.9316
# Epoch 8/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2929 - accuracy: 0.9359
# Epoch 9/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2685 - accuracy: 0.9274
# Epoch 10/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2479 - accuracy: 0.9274
# Epoch 11/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2285 - accuracy: 0.9274
# Epoch 12/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.2103 - accuracy: 0.9444
# Epoch 13/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1965 - accuracy: 0.9402
# Epoch 14/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1814 - accuracy: 0.9487
# Epoch 15/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1702 - accuracy: 0.9402
# Epoch 16/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1593 - accuracy: 0.9530
# Epoch 17/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1479 - accuracy: 0.9615
# Epoch 18/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1388 - accuracy: 0.9658
# Epoch 19/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1307 - accuracy: 0.9615
# Epoch 20/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1237 - accuracy: 0.9744
# Epoch 21/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1167 - accuracy: 0.9786
# Epoch 22/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1113 - accuracy: 0.9744
# Epoch 23/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.1076 - accuracy: 0.9744
# Epoch 24/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.1023 - accuracy: 0.9744
# Epoch 25/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0979 - accuracy: 0.9744
# Epoch 26/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0960 - accuracy: 0.9744
# Epoch 27/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0910 - accuracy: 0.9786
# Epoch 28/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0867 - accuracy: 0.9829
# Epoch 29/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0839 - accuracy: 0.9829
# Epoch 30/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0819 - accuracy: 0.9829
# Epoch 31/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0792 - accuracy: 0.9829
# Epoch 32/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0769 - accuracy: 0.9829
# Epoch 33/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0751 - accuracy: 0.9829
# Epoch 34/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0732 - accuracy: 0.9829
# Epoch 35/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0713 - accuracy: 0.9829
# Epoch 36/50
# 8/8 [==============================] - 0s 3ms/step - loss: 0.0698 - accuracy: 0.9829
# Epoch 37/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0682 - accuracy: 0.9829
# Epoch 38/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0666 - accuracy: 0.9829
# Epoch 39/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0654 - accuracy: 0.9829
# Epoch 40/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0636 - accuracy: 0.9829
# Epoch 41/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0639 - accuracy: 0.9829
# Epoch 42/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0614 - accuracy: 0.9829
# Epoch 43/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0603 - accuracy: 0.9829
# Epoch 44/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0593 - accuracy: 0.9829
# Epoch 45/50
# 8/8 [==============================] - 0s 5ms/step - loss: 0.0578 - accuracy: 0.9829
# Epoch 46/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0567 - accuracy: 0.9829
# Epoch 47/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0555 - accuracy: 0.9829
# Epoch 48/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0546 - accuracy: 0.9829
# Epoch 49/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0535 - accuracy: 0.9829
# Epoch 50/50
# 8/8 [==============================] - 0s 4ms/step - loss: 0.0523 - accuracy: 0.9829

# %% [markdown]
# EVALUATE THE MODLE

# %%
y_pred_probs = model.predict(X_test)
y_pred_classes = (y_pred_probs > 0.5).astype(int)
# Out:
# 4/4 [==============================] - 0s 3ms/step

# %%
accuracy = accuracy_score(y_test, y_pred_classes)
print(f"Accuracy on test data: {accuracy * 100:.2f}%")
# Out:
# Accuracy on test data: 93.97%
